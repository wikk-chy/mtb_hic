# %%
import coolbox
from coolbox.api import *

# %%
with MinValue(-7), MaxValue(-4):
    cool1 = Cool(cl1,resolution=5000,cmap="RdPu",style="triangular", orientation="inverted",depth_ratio=1.0,balance="KR")
    cool2 = Cool(cl2,resolution=5000,cmap="RdPu",style ='matrix',depth_ratio=1.0, balance="KR")
frame = XAxis() + cool2 
region = "Chromosome:0-4411532"
frame.plot(region)

# %%
fig=frame.plot(region)
fig.savefig("wtall2.pdf",format="pdf",dpi=500)
